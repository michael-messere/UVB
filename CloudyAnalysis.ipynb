# %% [markdown]
# # Cloudy Modeling of PDR and Dark Regions in Various Limiting Cases
# ## PS2 - Problem 3 - 3/4/24

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import QTable, Table, Column
from astropy import units as u
from astropy.io import ascii
import pandas as pd
import matplotlib
from scipy.interpolate import interp1d

# %matplotlib inline

params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)

import pyCloudy as pc
pc.log_.level = 3

# %%
dir_ = 'test/'
model_name = 'test'  
full_model_name = '{0}{1}'.format(dir_, model_name)

c_input = pc.CloudyInput(full_model_name)

c_input.print_input(to_file = True, verbose = False)
# Out:
# warng CloudyInput: "None" parameter not printed
#      CloudyInput: Input writen in test/test.in

# %% [markdown]
# ## __Load Data:__

# %%
radii = np.arange(0,1900,100)
model = []

for i in range(len(radii)):

    dir_ = 'runs/power_law_density_30kpc_disk_' + str(radii[i]) + '/'
    model_name = 'test'  
    full_model_name = '{0}{1}'.format(dir_, model_name)

    model.append(pc.CloudyModel(full_model_name))
# Out:
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_0/test
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: Number of zones: 535
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_0/test: runs/power_law_density_30kpc_disk_0/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_100/test
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: Number of zones: 518
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_100/test: runs/power_law_density_30kpc_disk_100/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_200/test
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: Number of zones: 487
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_200/test: runs/power_law_density_30kpc_disk_200/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_300/test
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: Number of zones: 473
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_300/test: runs/power_law_density_30kpc_disk_300/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_400/test
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: Number of zones: 451
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_400/test: runs/power_law_density_30kpc_disk_400/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_500/test
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: Number of zones: 441
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_500/test: runs/power_law_density_30kpc_disk_500/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_600/test
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: Number of zones: 441
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_600/test: runs/power_law_density_30kpc_disk_600/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_700/test
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: Number of zones: 435
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_700/test: runs/power_law_density_30kpc_disk_700/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_800/test
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: Number of zones: 432
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_800/test: runs/power_law_density_30kpc_disk_800/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_900/test
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: Number of zones: 424
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_900/test: runs/power_law_density_30kpc_disk_900/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1000/test
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: Number of zones: 413
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1000/test: runs/power_law_density_30kpc_disk_1000/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1100/test
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: Number of zones: 392
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1100/test: runs/power_law_density_30kpc_disk_1100/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1200/test
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: Number of zones: 384
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1200/test: runs/power_law_density_30kpc_disk_1200/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1300/test
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: Number of zones: 379
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1300/test: runs/power_law_density_30kpc_disk_1300/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1400/test
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: Number of zones: 373
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1400/test: runs/power_law_density_30kpc_disk_1400/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1500/test
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: Number of zones: 362
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1500/test: runs/power_law_density_30kpc_disk_1500/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1600/test
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: Number of zones: 362
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1600/test: runs/power_law_density_30kpc_disk_1600/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1700/test
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: Number of zones: 351
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1700/test: runs/power_law_density_30kpc_disk_1700/test.cont read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: Creating CloudyModel for runs/power_law_density_30kpc_disk_1800/test
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.rad read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: Number of zones: 343
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.phy read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_H read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling H with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_He read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling He with 3 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_C read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling C with 13 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_N read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling N with 8 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_O read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling O with 12 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_Ne read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling Ne with 11 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_Ar read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling Ar with 19 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_S read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling S with 17 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_Cl read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling Cl with 18 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_Fe read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling Fe with 27 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.ele_Si read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: filling Si with 15 columns
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.emis read
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: Number of emissivities: 16
#      CloudyModel runs/power_law_density_30kpc_disk_1800/test: runs/power_law_density_30kpc_disk_1800/test.cont read

# %% [markdown]
# ## __Calculate Number Density:__

# %%
plt.rcParams['font.family'] = 'serif'
from matplotlib.gridspec import GridSpec

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10), frameon=False)
plt.subplots_adjust(wspace=0.1, hspace=0.0)

num_segments = len(model)
cmap = plt.cm.coolwarm(np.linspace(0.1, 0.9, num_segments))

i = 0

ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 0)[::-1]*model[i].nH[::-1], label = 'HI, z = [0.0,1.8] kpc',color=cmap[i],ls='-')
ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 1)[::-1]*model[i].nH[::-1], label = 'HII, z = [0.0,1.8] kpc',color=cmap[i],ls='--')

for i in range(len(radii)):
    
    print(np.max(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21)))
    
    ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 0)[::-1]*model[i].nH[::-1],color=cmap[i],ls='-')
    ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 1)[::-1]*model[i].nH[::-1],color=cmap[i],ls='--')

ax.set_xlabel('Radius [kpc]',fontsize=14,labelpad=15)
ax.set_ylabel(r'Number Density [cm$^{-3}$]',fontsize=14,labelpad=15)

ax.set_yscale('log')

ax.legend(loc='upper right',fontsize=15,ncol=4, fancybox=False,edgecolor='black')

plt.plot()
# Out:
# 28.73529411764696
# 28.73856209150324
# 28.732026143790904
# 28.722222222222285
# 28.73856209150324
# 28.722222222222285
# 28.64705882352939
# 28.69281045751643
# 28.709150326797158
# 28.722222222222285
# 28.73529411764696
# 28.728758169934622
# 28.69934640522854
# 28.70261437908505
# 28.70261437908505
# 28.722222222222285
# 28.728758169934622
# 28.712418300653667
# 28.732026143790904
# []

# %% [markdown]
# ### __Interpolate Radial Number Density Profile:__

# %%
plt.rcParams['font.family'] = 'serif'
from matplotlib.gridspec import GridSpec

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10), frameon=False)
plt.subplots_adjust(wspace=0.1, hspace=0.0)

num_segments = len(model)
cmap = plt.cm.coolwarm(np.linspace(0.1, 0.9, num_segments))

i = 0

ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 0)[::-1]*model[i].nH[::-1], label = 'HI, z = [0.0,1.8] kpc',color=cmap[i],ls='-')
ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 1)[::-1]*model[i].nH[::-1], label = 'HII, z = [0.0,1.8] kpc',color=cmap[i],ls='--')

H_p0_interp = []
H_p1_interp = []

for i in range(len(model)):

    ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 0)[::-1]*model[i].nH[::-1],color=cmap[i],ls='-')
    ax.plot(np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21), model[i].get_ionic('H', 1)[::-1]*model[i].nH[::-1],color=cmap[i],ls='--')
    
    x = np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21)
    y = model[i].get_ionic('H', 0)[::-1]*model[i].nH[::-1]
    interp_linear = interp1d(x, y, kind='linear')
    x_new = np.linspace(0, 28.6, 1000) 
    y_new_linear = interp_linear(x_new)
    H_p0_interp.append(y_new_linear)
    ax.plot(x_new,y_new_linear,color='black',ls='-',lw=0.8)

    x = np.abs(model[i].radius[::-1]/3.06e21-model[i].radius[-1]/3.06e21)
    y = model[i].get_ionic('H', 1)[::-1]*model[i].nH[::-1]
    interp_linear = interp1d(x, y, kind='linear')
    x_new = np.linspace(0, 28.6, 1000)  
    y_new_linear = interp_linear(x_new)
    H_p1_interp.append(y_new_linear)
    ax.plot(x_new,y_new_linear,color='black',ls='--',lw=0.8)
    
ax.set_xlabel('Radius [kpc]',fontsize=14,labelpad=15)
ax.set_ylabel(r'Number Density [cm$^{-3}$]',fontsize=14,labelpad=15)

ax.set_yscale('log')

ax.legend(loc='upper right',fontsize=15,ncol=4, fancybox=False,edgecolor='black')

plt.plot()
# Out:
# []

# %%
H_p0_interp = np.array(H_p0_interp)
H_p1_interp = np.array(H_p1_interp)

# %%
np.minH_p0_interp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [636], in <cell line: 1>()
# ----> 1 np.minH_p0_interp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/__init__.py:313, in __getattr__(attr)
#     310     from .testing import Tester
#     311     return Tester
# --> 313 raise AttributeError("module {!r} has no attribute "
#     314                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'minH_p0_interp'

# %%
zheight = np.arange(0,1900,100)

plt.rcParams['font.family'] = 'serif'
from matplotlib.gridspec import GridSpec

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10), frameon=False)
plt.subplots_adjust(wspace=0.1, hspace=0.0)

num_segments = 1000
cmap = plt.cm.coolwarm(np.linspace(0.1, 0.9, num_segments))

for i in range(1000):

    ax.plot(zheight,H_p0_interp[:,i],color=cmap[i])
    
ax.set_yscale('log')

sm = plt.cm.ScalarMappable(cmap=plt.cm.coolwarm, norm=plt.Normalize(vmin=min(x_new), vmax=max(x_new)))
sm.set_array([]) 

cbar = plt.colorbar(sm, pad = 0.01)
cbar.set_label('R [kpc]', fontsize=16, labelpad = 15)

ax.set_ylabel(r'n$_\mathrm{HI}$ $[cm^{-3}]$',fontsize=16)
ax.set_xlabel(r'z-Height [kpc]',fontsize=16)
# Out:
# Text(0.5, 0, 'z-Height [kpc]')

# %%
zheight = np.arange(0,1900,100)

plt.rcParams['font.family'] = 'serif'
from matplotlib.gridspec import GridSpec

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10), frameon=False)
plt.subplots_adjust(wspace=0.1, hspace=0.0)

num_segments = 1
cmap = plt.cm.coolwarm(np.linspace(0.1, 0.9, num_segments))

for i in range(1):

    ax.plot(zheight,H_p0_interp[:,i],color=cmap[i])
    
ax.set_yscale('log')

sm = plt.cm.ScalarMappable(cmap=plt.cm.coolwarm, norm=plt.Normalize(vmin=min(x_new), vmax=max(x_new)))
sm.set_array([]) 

cbar = plt.colorbar(sm, pad = 0.01)
cbar.set_label('R [kpc]', fontsize=16, labelpad = 15)

ax.set_ylabel(r'n$_\mathrm{HI}$ $[cm^{-3}]$',fontsize=16)
ax.set_xlabel(r'z-Height [kpc]',fontsize=16)
# Out:
# Text(0.5, 0, 'z-Height [kpc]')

# %%
i = 0
np.nansum(H_p0_interp[:,i])*3.086e+18*1800
# Out:
# 3.800630082891601e+22

# %%
i = 500
np.nansum(H_p0_interp[:,i])*3.086e+18*1800
# Out:
# 2.0893483645835297e+19

# %%
zheight = np.arange(0,1900,100)

plt.rcParams['font.family'] = 'serif'
from matplotlib.gridspec import GridSpec

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10), frameon=False)
plt.subplots_adjust(wspace=0.1, hspace=0.0)

skip = [0,100,200,300,400,500,600,700,800,900,999]
num_segments = 1000
cmap = plt.cm.coolwarm(np.linspace(0.1, 0.9, num_segments))

for i in skip:#range(1000):

    ax.plot(zheight,H_p1_interp[:,i],color=cmap[i])
    
ax.set_yscale('log')

sm = plt.cm.ScalarMappable(cmap=plt.cm.coolwarm, norm=plt.Normalize(vmin=min(x_new), vmax=max(x_new)))
sm.set_array([]) 

cbar = plt.colorbar(sm, pad = 0.01)
cbar.set_label('R [kpc]', fontsize=16, labelpad = 15)

ax.set_ylabel(r'n$_\mathrm{HII}$ $[cm^{-3}]$',fontsize=16)
ax.set_xlabel(r'z-Height [kpc]',fontsize=16)
# Out:
# Text(0.5, 0, 'z-Height [kpc]')

# %% [markdown]
# ## __Calculate Column Density:__

# %%
# number density profile

plt.figure(figsize=(8,5))
plt.scatter(power_law_density_30kpc_disk_0.radius/3.086e21, power_law_density_30kpc_disk_0.nH, color = 'black',label='Constant')
plt.scatter(power_law_density_30kpc_disk_500.radius/3.086e21, power_law_density_30kpc_disk_500.nH, color = 'red',label='Constant')
plt.xlabel('Radius',fontsize=14)
plt.ylabel(r'n$_\mathrm{H}$ $[cm^{-3}]$',fontsize=14)
plt.legend(loc=3,fontsize=12)

# %%
# Plot ionization fractions (for Problem 1, and useful for 2 and 3)
plt.figure(figsize=(8,8))
#plt.scatter(model.radius/3.06e21, model.nH, label = 'HII')
plt.scatter(power_law_density_30kpc_disk_0.radius/3.06e21, power_law_density_30kpc_disk_0.get_ionic('H', 0), label = 'HI')
plt.scatter(power_law_density_30kpc_disk_0.radius/3.06e21, power_law_density_30kpc_disk_0.get_ionic('H', 1), label = 'HII')
#plt.scatter(power_law_density_30kpc_disk_0.radius/3.06e21, power_law_density_30kpc_disk_0.get_ionic('H', 2), label = 'HII')
#plt.plot(model.radius, model.get_ionic('He', 0), label = 'HeI')
#plt.plot(model.radius, model.get_ionic('He', 1), label = 'HeII')
#plt.plot(model.radius, model.get_ionic('He', 2), label = 'HeIII')
plt.xlabel('Radius',fontsize=14)
plt.ylabel(r'$x_{ion}$',fontsize=14)
plt.title('Midplane, z = 0',fontsize=18)
plt.legend(loc=3,fontsize=12)
plt.yscale('log')

# %%
plt.rcParams['font.family'] = 'serif'
from matplotlib.gridspec import GridSpec

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10), frameon=False)
plt.subplots_adjust(wspace=0.1, hspace=0.0)

ax.plot(np.abs(power_law_density_30kpc_disk_0.radius[::-1]/3.06e21-power_law_density_30kpc_disk_0.radius[-1]/3.06e21), power_law_density_30kpc_disk_0.get_ionic('H', 0)[::-1]*power_law_density_30kpc_disk_0.nH[::-1], label = 'HI, z = 0.0 kpc',color='black')
ax.plot(np.abs(power_law_density_30kpc_disk_0.radius[::-1]/3.06e21-power_law_density_30kpc_disk_0.radius[-1]/3.06e21), power_law_density_30kpc_disk_0.get_ionic('H', 1)[::-1]*power_law_density_30kpc_disk_0.nH[::-1], label = 'HII, z = 0.0 kpc',color='salmon')

ax.plot(np.abs(power_law_density_30kpc_disk_500.radius[::-1]/3.06e21-power_law_density_30kpc_disk_500.radius[-1]/3.06e21), power_law_density_30kpc_disk_500.get_ionic('H', 0)[::-1]*power_law_density_30kpc_disk_500.nH[::-1], label = 'HI, z = 0.5 kpc',color='black', ls = '--')
ax.plot(np.abs(power_law_density_30kpc_disk_500.radius[::-1]/3.06e21-power_law_density_30kpc_disk_500.radius[-1]/3.06e21), power_law_density_30kpc_disk_500.get_ionic('H', 1)[::-1]*power_law_density_30kpc_disk_500.nH[::-1], label = 'HII, z = 0.5 kpc',color='salmon', ls = '--')

ax.plot(np.abs(power_law_density_30kpc_disk_1000.radius[::-1]/3.06e21-power_law_density_30kpc_disk_1000.radius[-1]/3.06e21), power_law_density_30kpc_disk_1000.get_ionic('H', 0)[::-1]*power_law_density_30kpc_disk_1000.nH[::-1], label = 'HI, z = 1.0 kpc',color='black', ls = '-.')
ax.plot(np.abs(power_law_density_30kpc_disk_1000.radius[::-1]/3.06e21-power_law_density_30kpc_disk_1000.radius[-1]/3.06e21), power_law_density_30kpc_disk_1000.get_ionic('H', 1)[::-1]*power_law_density_30kpc_disk_1000.nH[::-1], label = 'HII, z = 1.0 kpc',color='salmon', ls = '-.')

ax.plot(np.abs(power_law_density_30kpc_disk_1500.radius[::-1]/3.06e21-power_law_density_30kpc_disk_1500.radius[-1]/3.06e21), power_law_density_30kpc_disk_1500.get_ionic('H', 0)[::-1]*power_law_density_30kpc_disk_1500.nH[::-1], label = 'HI, z = 1.5 kpc',color='black', ls = '-.')
ax.plot(np.abs(power_law_density_30kpc_disk_1500.radius[::-1]/3.06e21-power_law_density_30kpc_disk_1500.radius[-1]/3.06e21), power_law_density_30kpc_disk_1500.get_ionic('H', 1)[::-1]*power_law_density_30kpc_disk_1500.nH[::-1], label = 'HII, z = 1.5 kpc',color='salmon', ls = '-.')


ax.set_xlabel('Radius [kpc]',fontsize=14,labelpad=15)
ax.set_ylabel(r'Number Density [cm$^{-3}$]',fontsize=14,labelpad=15)

ax.set_yscale('log')

ax.legend(loc='upper right',fontsize=15,ncol=4, fancybox=False,edgecolor='black')

plt.plot()
# Out:
# []

# %%
# Plot ionization fractions (for Problem 1, and useful for 2 and 3)
plt.figure(figsize=(8,8))
#plt.scatter(model.radius/3.06e21, model.nH, label = 'HII')
plt.scatter(power_law_density_30kpc_disk_500.radius/3.06e21, power_law_density_30kpc_disk_500.get_ionic('H', 0), label = 'HI')
plt.scatter(power_law_density_30kpc_disk_500.radius/3.06e21, power_law_density_30kpc_disk_500.get_ionic('H', 1), label = 'HII')
#plt.plot(model.radius, model.get_ionic('He', 0), label = 'HeI')
#plt.plot(model.radius, model.get_ionic('He', 1), label = 'HeII')
#plt.plot(model.radius, model.get_ionic('He', 2), label = 'HeIII')
plt.xlabel('Radius',fontsize=14)
plt.ylabel(r'$x_{ion}$',fontsize=14)
plt.title('Ionization Zones',fontsize=18)
plt.legend(loc=3,fontsize=12)
plt.yscale('log')

# %%
(model_power_law_faraway.radius[-1] - model_power_law_faraway.radius[0]) / 3.086e21
# Out:
# 29.93519118600133

# %%
def function(x):
    
    return 1.5*np.exp(-x/2.300)

# %%
def function(x):
    
    return 1.5*np.exp(-x/(2300)

# %%
def function_total(R,z):
    
    return 1.5*np.exp(-R/2300)*np.exp(-np.abs(z)/426)

# %%
plt.rcParams['font.family'] = 'serif'
from matplotlib.gridspec import GridSpec

R = np.arange(0,30000,1)
z = np.arange(0,5000,50)

num_segments = len(z)
cmap = plt.cm.coolwarm(np.linspace(0.1, 0.9, num_segments))

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10), frameon=False)
plt.subplots_adjust(wspace=0.1, hspace=0.0)

for i in range(len(z)):
    
    y = function_total(R,z[i])
    
    ax.plot(R,y,color=cmap[i],lw=3)
    
sm = plt.cm.ScalarMappable(cmap=plt.cm.coolwarm, norm=plt.Normalize(vmin=min(z/1000), vmax=max(z/1000)))
sm.set_array([])  # Set empty array

cbar = plt.colorbar(sm, pad = 0.01)
cbar.set_label('z-Height [kpc]', fontsize=16, labelpad = 15)

ax.set_ylabel(r'n$_\mathrm{H}$ $[cm^{-3}]$',fontsize=16)
ax.set_xlabel(r'R [kpc]',fontsize=16)

ax.set_yscale('log')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'serif'

R = np.arange(0, 30000, 100)
z = np.arange(0, 5000, 100)

# Compute z values using function_total for each (R, z) pair
zvalue = np.zeros((len(z), len(R)))

for i in range(len(z)):
    for j in range(len(R)):
        zvalue[i, j] = function_total(R[j], z[i])

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 5))

# Plot the imshow with z values as the color
im = ax.imshow(np.flip(zvalue,axis=0), extent=[R.min()/1000, R.max()/1000, z.min()/1000, z.max()/1000], aspect='auto', cmap='coolwarm', norm = matplotlib.colors.LogNorm())

# Create a colorbar
cbar = plt.colorbar(im, ax=ax, pad = 0.01)
cbar.set_label(r'n$_\mathrm{H}$ $[cm^{-3}]$', fontsize=14, labelpad = 10)

# Set labels and scale for axes
ax.set_xlabel('R [kpc]', fontsize=14)
ax.set_ylabel('z [kpc]', fontsize=14)

for i in np.arange(0,2100/1000,100/1000):

    ax.axhline(i,color='black',ls='-',lw=1,alpha=1,zorder=20)

# Show the plot
plt.show()

# %%
10.6 Double optical depths

# %%
def fit_function(x,alpha):
    
    return 1.5*((x-30000)/2300)**alpha

import scipy

yfit, _ = scipy.optimize.curve_fit(fit_function,x,y,p0=[-2])
# Out:
# /Users/messeremichael/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
def fit_function(x,alpha):
    
    return 1.5*(x/1030000)**alpha

import scipy

#yfit, _ = scipy.optimize.curve_fit(fit_function,x,y,p0=[-2])

# %%
def fit_function2(x,alpha):
    
    return 2.5080728198509695e-06*(x/1000000)**alpha

# %%
np.log10(2.5080728198509695e-06)
# Out:
# -5.600659858271809

# %%
def function(x):
    
    return 1.5*np.exp((x-1030000)/2300)

# %%
def function_total(R,z):
    
    return 1.5*np.exp((R-1030000)/2300)*np.exp(-np.abs(z)/426)

# %%
def fit_function2(x,alpha):
            
    return 10**(constant_value[i])*(x/1000000)**alpha

# %%
x = np.arange(1000000,1030000,10)

constant_value = []

for i in np.arange(0,5100,100):
    
    constant = function_total(x,i)[0]
    
    constant_value.append(np.log10(constant))

# %%
x = np.arange(1000000,1030000,10)

alpha_value = []

for i, zheight in enumerate(np.arange(0,5100,100)):
        
    y = function_total(x,zheight)
    yfit, _ = scipy.optimize.curve_fit(fit_function2,x,y,p0=[450])
    
    alpha_value.append(yfit[0])

# %%
alpha_value
# Out:
# [441.0401063429482,
#  441.0401063429551,
#  441.04010634294764,
#  441.04010634296486,
#  441.0401063429502,
#  441.0401063429613,
#  441.0401063429493,
#  441.04010634295145,
#  441.0401063429513,
#  441.0401063429619,
#  441.040106342953,
#  441.0401063429565,
#  441.0401063429526,
#  441.0401063429559,
#  441.04010634296424,
#  441.0401063429528,
#  441.04010634295526,
#  441.0401063429572,
#  441.0401063429612,
#  441.04010634296,
#  441.04010634295014,
#  441.04010634294644,
#  441.0401063429531,
#  441.0401063429594,
#  441.04010634295196,
#  441.0401063429481,
#  441.04010634295565,
#  441.0401063429427,
#  441.04010634296026,
#  441.040106342957,
#  441.04010634296026,
#  441.04010634296117,
#  441.04010634295327,
#  441.0401063429493,
#  441.0401063429595,
#  441.040106342949,
#  441.0401063429583,
#  441.04010634295565,
#  441.0401063429558,
#  441.0401063429531,
#  441.040106342959,
#  441.0401063429449,
#  441.04010634295577,
#  441.040106342947,
#  441.0401063429575,
#  441.0401063429557,
#  441.0401063429552,
#  441.0401063429582,
#  441.0401063429446,
#  441.04010634295975,
#  441.0401063429533]

# %%
constant_value
# Out:
# [-5.488619374464995,
#  -5.590566435944631,
#  -5.692513497424268,
#  -5.794460558903904,
#  -5.896407620383541,
#  -5.998354681863177,
#  -6.100301743342814,
#  -6.2022488048224504,
#  -6.304195866302087,
#  -6.4061429277817235,
#  -6.50808998926136,
#  -6.610037050740997,
#  -6.711984112220633,
#  -6.81393117370027,
#  -6.915878235179907,
#  -7.017825296659543,
#  -7.11977235813918,
#  -7.221719419618816,
#  -7.323666481098453,
#  -7.425613542578089,
#  -7.527560604057726,
#  -7.629507665537362,
#  -7.731454727016999,
#  -7.833401788496636,
#  -7.935348849976272,
#  -8.037295911455908,
#  -8.139242972935545,
#  -8.241190034415183,
#  -8.343137095894818,
#  -8.445084157374456,
#  -8.547031218854093,
#  -8.64897828033373,
#  -8.750925341813366,
#  -8.852872403293002,
#  -8.954819464772639,
#  -9.056766526252275,
#  -9.158713587731912,
#  -9.260660649211548,
#  -9.362607710691185,
#  -9.464554772170821,
#  -9.566501833650458,
#  -9.668448895130094,
#  -9.77039595660973,
#  -9.872343018089367,
#  -9.974290079569004,
#  -10.07623714104864,
#  -10.178184202528277,
#  -10.280131264007913,
#  -10.38207832548755,
#  -10.484025386967186,
#  -10.585972448446823]

# %%
i = 0
x = np.arange(1000000,1030000,10)
#plt.plot(x,function(x),color='black')
plt.plot((x-1e6)/1000,function_total(x,0),color='black')
#plt.plot(x,fit_function(x,yfit),color='red')
#plt.plot(x,fit_function(x,450),color='red')
#plt.plot(x,fit_function2(x,441),color='green')
plt.plot((x-1e6)/1000,fit_function2(x,441.04),color='green')
#plt.ylim(0,3)

# %%
redisuals = function_total(x,100) - fit_function2(x,441.04)

# %%
plt.plot(x,redisuals)

# %%
x = np.arange(1000000,1030000,10)
#plt.plot(x,function(x),color='black')
#plt.plot(x,fit_function(x,yfit),color='red')
plt.plot(x,fit_function(x,450),color='red')
plt.plot(x,fit_function2(x,283),color='green')
#plt.ylim(0,3)

# %%
def function_total(R,z):
    
    return 1.5*np.exp((R-1030000)/2300)*np.exp(-np.abs(z)/426)

# %%
x = np.arange(1000000,1030000,10)
plt.plot(x,function_total(x,0),color='black')
plt.plot(x,function_total(x,100),color='black')
plt.plot(x,function_total(x,1000),color='black')

# %%
# Plot ionization fractions (for Problem 1, and useful for 2 and 3)
plt.figure(figsize=(8,8))
plt.scatter(model.radius/3.06e21, model.nH, label = 'HII')
#plt.scatter(model.radius, model.get_ionic('H', 0), label = 'HI')
#plt.plot(model.radius, model.get_ionic('He', 0), label = 'HeI')
#plt.plot(model.radius, model.get_ionic('He', 1), label = 'HeII')
#plt.plot(model.radius, model.get_ionic('He', 2), label = 'HeIII')
plt.xlabel('Radius',fontsize=14)
plt.ylabel(r'$x_{ion}$',fontsize=14)
plt.title('Ionization Zones',fontsize=18)
plt.legend(loc=3,fontsize=12)
plt.yscale('log')

# %%
pc.config.cloudy_exe = '/Users/messeremichael/Documents/Software/c23.01/source/cloudy.exe'

for i in range(7):
    
    dir_ = 'pdr/'
    model_name = 'ps2_pdr' + str(i)   
    full_model_name = '{0}{1}'.format(dir_, model_name)
    
    c_input = pc.CloudyInput(full_model_name)
    
    pc.log_.message('Running {0}'.format(model_name), calling = 'test1')
    pc.log_.timer('Starting Cloudy', quiet = True, calling = 'test1')
    
    c_input.run_cloudy()
    pc.log_.timer('Cloudy ended after seconds:', calling = 'test1')

# %% [markdown]
# ## Reading the Output
#
# These can be used to read main cloudy input files  .ovr (overview), .mol (species densities), .col (cooling rates and fractions), .het (heating rates and fractions)

# %%
# Functions for reading main cloudy input files  .ovr (overview), .mol (species densities), .col (cooling rates and fractions), .het (heating rates and fractions)

def read_overview(model_name,path):
    file=model_name+'.ovr'
    return(Table.from_pandas(pd.read_table(path+file)))

def read_molecule(model_name,path):
    file=model_name+'.mol'
    return(Table.from_pandas(pd.read_table(path+file)))

def read_cooling(model_name,path):
    file=path+model_name+'.col'
    with open(file) as f:
        ftable = f.readlines()
    f.close()
    rows=len(ftable)    
    
    # First find which molecule/processes are listed in the cooling table at a given radii
    coolstr=[]
    for line in ftable[1:rows]:     # skip comment header
        row = [item.strip() for item in line.split('\t')]
        lrow=len(row)
         # find process string in every other, starting at 6th column
        coolstr=np.concatenate((coolstr,np.array(row[5:lrow:2])))  

    # Make an array of the unique labels from above    
    cool_unique=np.unique(coolstr)

    # Build two arrays to contain the cooling table info, and the cooling fraction
    ulen=len(cool_unique)
    info=['depth_cm','Temp','Heat_tot','Cool_tot','NotUsed']
    coolarr_info=np.zeros((rows-1,5),dtype='float64')
    coolarr_frac=np.zeros((rows-1,ulen),dtype='float64')

    # Now cycle through file again to extract info and cooling fractions for each entry found in the table
    for line,index in zip(ftable[1:rows],np.arange(rows-1)):
        row = [item.strip() for item in line.split('\t')]
        lrow=len(row)
        coolarr_info[index,:]=np.float64(np.array(row[0:5]))
        # find process string in every other, starting at 6th column
        typestr=np.array(row[5:lrow:2])   
        # find fraction is then in every other, starting at 7th column
        val=np.float64(np.array(row[6:lrow:2]))
        for t,v in zip(typestr,val):
            p=np.argwhere(t==cool_unique)
            coolarr_frac[index,p[0]]=v

    t_cool_info=Table(coolarr_info,names=info)
    t_cool_frac=Table(coolarr_frac,names=cool_unique)
    return(t_cool_info,t_cool_frac)

def read_heating(model_name,path):
    file=path+model_name+'.het'
    with open(file) as f:
        ftable = f.readlines()
    f.close()
    # for heating, there may be more rows than we want
    init_rows=len(ftable)    
    rowflg=np.zeros(init_rows)


    # First find which molecule/processes are listed in the heating table at a given radii
    heatstr=[]
    for line,index in zip(ftable[1:init_rows],np.arange(init_rows-1)):     # skip comment header
        row = [item.strip() for item in line.split('\t')]
        lrow=len(row)
        if (lrow>5):
         # find process string in every other, starting at 6th column
            heatstr=np.concatenate((heatstr,np.array(row[5:lrow:2])))  
            rowflg[index+1]=1    # +1 to account for header line
    
    rows=np.sum(rowflg).astype("int64")
    ftable_tmp=np.array(ftable)
    p=np.where(rowflg==1)
    ftable=ftable_tmp[p[0]]   # note this table has no header
    
    # Make an array of the unique labels from above    
    heat_unique=np.unique(heatstr)

    # Build two arrays to contain the cooling table info, and the cooling fraction
    ulen=len(heat_unique)
    info=['depth_cm','Temp','Heat_tot','Cool_tot','NotUsed']
    heatarr_info=np.zeros((rows,5),dtype='float64')    # slightly different from cool arr since no header
    heatarr_frac=np.zeros((rows,ulen),dtype='float64')   # slightly different from cool arr since no header


    # Now cycle through file again to extract info and cooling fractions for each entry found in the table
    for line,index in zip(ftable[0:rows],np.arange(rows)):
        row = [item.strip() for item in line.split('\t')]
        lrow=len(row)
        heatarr_info[index,:]=np.float64(np.array(row[0:5]))
        # find process string in every other, starting at 6th column
        typestr=np.array(row[5:lrow:2])   
        # find fraction is then in every other, starting at 7th column
        val=np.float64(np.array(row[6:lrow:2]))
        for t,v in zip(typestr,val):
            p=np.argwhere(t==heat_unique)
            heatarr_frac[index,p[0]]=v

    t_heat_info=Table(heatarr_info,names=info)
    t_heat_frac=Table(heatarr_frac,names=heat_unique)
    return(t_heat_info,t_heat_frac)

# %%
t_ovr = []    
t_mol = []   
t_cool_info = []
t_cool_frac = []   
t_heat_info = []
t_heat_frac = []

for i in range(7):
    
    path = 'pdr/'
    model_name = 'ps2_pdr' + str(i)   
    
    t_ovr.append(read_overview(model_name,path))
    t_mol.append(read_molecule(model_name,path))
    t_cool_info_temp, t_cool_frac_temp = read_cooling(model_name,path)
    t_cool_info.append(t_cool_info_temp)
    t_cool_frac.append(t_cool_frac_temp)
    t_heat_info_temp, t_heat_frac_temp = read_heating(model_name,path)
    t_heat_info.append(t_heat_info_temp)
    t_heat_frac.append(t_heat_frac_temp)

# %% [markdown]
# ## Plotting Functions

# %%
def frac_stackplot(t_frac,x,xlabel,title):

    cm = plt.get_cmap('tab20b')
    y=np.lib.recfunctions.structured_to_unstructured(t_frac.as_array())

    labels=t_frac.colnames
    nlabel=len(labels)

    plt.figure(figsize=(9,6))

    plt.stackplot(x,np.transpose(y),labels=labels,colors=cm(np.arange(len(labels))/len(labels)),ec='k')
    plt.legend()
    plt.xlabel(xlabel)
    plt.title(title)
    plt.ylabel('Fraction')
    #plt.xscale("log")
    #plt.yscale("log")
    plt.show()

# %% [markdown]
# ## Problem 4a

# %% [markdown]
# For the fiducial PDR/dark region – how do species ionization and fractions and **molecular compositions** vary with Av?  In each region (low Av, high Av) which processes dominate the heating and cooling rates?

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)

# %% [markdown]
# In the cooling plot above, it can be seen that when A$_v$ < 5, dust, Si, O, and C dominate compared to the presence of molecules when A$_v$ > 5. This is a result of these molecules being dissociated at smaller values of A$_v$, since they are closer to the radiation source. At low A$_v$, recombination domates. Further into the dark region at high A$_v$, cooling is dominated by molecular rotational transitions.

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

# %% [markdown]
# In the heating plot above, it can be seen that when A$_v$ < 5, GrnP dominates compared to the presence of H2dH and CRH when A$_v$ > 5. In this dark region, it is expected that heating is small and dominated by cosmic rays. There is no photo-ionization at this depth, which we saw closer to the radiation source in the previous homework. There could also be heating due to turbulence, ambipolar diffusion, gravitational heating, and collisons between gas and warm dust grains. GrnP stands for grain photoelectric effect. This is heating due to photons hitting electrons off of dust grains. There is also GrnC, or grain collisions, which increases slightly as GrnP decreases. This is likely due to the density of these inner regions increasing. H2dH represents molecular hydrogen (H$_2$) dissociation and CRH is cosmic ray heating.

# %%
# This is an example of species to plot, you might want to select others from above!
pltspecies=['H','H+','H-','H2','H3+','He+','C','C+','O','O+','CO','OH','H2O']
nspecies=len(pltspecies)

cm = plt.get_cmap('gist_rainbow')
colors=cm(np.arange(nspecies)/nspecies)

plt.figure(figsize=(9,6)) 
for species,color in zip(pltspecies,colors):
    plt.plot(t_mol[i]['AV(point)'],t_mol[i][species]/t_ovr[i]['hden'],label=species,color=color)
   
plt.legend()
plt.yscale("log")
plt.xlabel("$A_V$")
plt.ylabel("n(species)/n(H)")
plt.title("Fractional species/ion abundance: "+model_name)
#plt.xlim((2,5))
plt.ylim((1e-11,2))
plt.show()

# %% [markdown]
# In the above plot, we find that H species dominate across the region. For example, in the inner region where the temperature is highest, H dominates and then there is a sharp transition into H$_2$ at A$_v$ > 2. H+ also sharply drops off at A$_v$ = 0 and there is a small presence of H- below A$_v$ = 1. O remains fairly constant across the region while O+ decreases (similar to H+ decreasing, owing to the increase in density).
#
# CO, OH, and H$_2$O increase at A$_v$ > 2, since they can survive at these distances from the radiation source without being dissociated.

# %%
plt.figure(figsize=(9,6))
plt.plot(t_ovr[i]['AV(point)'],t_ovr[i]['Te'])
plt.yscale("log")
plt.ylabel("$T_e$")
plt.xlabel("$A_V$")
plt.title("Temperature vs. A$_V$: "+model_name)
plt.show()

plt.figure(figsize=(9,6))
plt.plot(t_ovr[i]['AV(point)'],t_ovr[i]['eden']/t_ovr[i]['hden'])
plt.yscale("log")
plt.ylabel("$n_e/n_H$")
plt.xlabel("$A_V$")
plt.title("Fractional electron density vs. A$_V$:"+model_name)
plt.show()

# %% [markdown]
# In the two plots above, the temperature and fractional electron density decrease further into the cloud (as A$_v$ increases). This is a result of material being more shielded from the radiation source at large A$_v$.

# %% [markdown]
# ## Problem 4b

# %% [markdown]
# #### Changing Density:

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)  

i = 1
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)    

i = 2
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)

# %% [markdown]
# If you decrease the density to Hden = 2, then CH 0.0 dominates when A$_v$ < 2 and C 10.0 dominates when A$_v$ > 2. However, O 10.0 increases slowly as A$_v$ approaches 10.
#
# If the density increases to Hden = 6, then the CH 0.0 and C 10.0 no longer dominate. Intead, dust dominates at A$_v$ < 2 and O 10.0 dominates in the interval A$_v$ = [2, 8]. Similar to the intermediate density model, CO dominates at A$_v$ > 8.

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

i = 1
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

i = 2
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

# %% [markdown]
# If you decrease the density, then the distribution is similar to the intermediate density model except that the grain photoelectric effect only dominates the heating up to A$_v$ = 2, instead of A$_v$ = 4. Cosmic ray heating and molecular hydrogen dissociation nearly equally contribute to the heating at A$_v$ > 2.
#
# If the density is increased, then the heating of the region out to A$_v$ = 6 is dominated by the grain photoelectric effect. The inner dark region is dominated by grain collisions, likely due to the increase in density.

# %%
i_values = [0, 1, 2]
model_names = ['ps2_pdr' + str(i) for i in i_values]

pltspecies=['H','H+','H-','H2','H3+','He+','C','C+','O','O+','CO','OH','H2O']
nspecies=len(pltspecies)

cm = plt.get_cmap('gist_rainbow')
colors=cm(np.arange(nspecies)/nspecies)

plt.figure(figsize=(18,4))

for idx, i in enumerate(i_values, start=1):
    plt.subplot(1, 3, idx)
    for species,color in zip(pltspecies,colors):
        plt.plot(t_mol[i]['AV(point)'],t_mol[i][species]/t_ovr[i]['hden'],label=species,color=color)
    plt.legend()
    plt.yscale("log")
    plt.xlabel("$A_V$")
    plt.ylabel("n(species)/n(H)")
    plt.title("Fractional species/ion abundance: " + model_names[idx-1])
    plt.ylim((1e-11,2))

plt.tight_layout()
plt.show()

# %% [markdown]
# It seems that the largest effect of decreasing/increasing the density parameter is the location at which molecules start to form. As the density increases from 2 to 6, the relative enhancement of H$_2$, CO, OH, and H$_2$O increases to larger values of A_$v$.

# %%
i_values = [1, 2, 3]
model_names = ['ps2_pdr' + str(i) for i in i_values]

plt.figure(figsize=(14, 10))

for idx, i in enumerate(i_values, start=1):
    plt.subplot(3, 2, idx*2-1)
    plt.plot(t_ovr[i]['AV(point)'], t_ovr[i]['Te'])
    plt.yscale("log")
    plt.ylabel("$T_e$")
    plt.xlabel("$A_V$")
    plt.title("Temperature vs. A$_V$: " + model_names[idx-1])

    plt.subplot(3, 2, idx*2)
    plt.plot(t_ovr[i]['AV(point)'], t_ovr[i]['eden'] / t_ovr[i]['hden'])
    plt.yscale("log")
    plt.ylabel("$n_e/n_H$")
    plt.xlabel("$A_V$")
    plt.title("Fractional electron density vs. A$_V$: " + model_names[idx-1])

plt.tight_layout()
plt.show()

# %% [markdown]
# As the density increases from 2 to 6, it can be seen in the above plots that both the temperature and fractional electron density drop off more rapidly. However, there is less of a difference between 4/6 than 2/4. At hden = 4, there seems to be an enhancement of temperature at A$_v$ > 2 whereas there is no increase at hden = 6.

# %% [markdown]
# ### Changing Metal-Grain Ratio:

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)  

i = 3
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)    

i = 4
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)

# %% [markdown]
# If we increase the metal/grain ratio from the middle to top to bottom panel, we find that dust, O, and Si dominate in cooling at low A$_v$. The maximum C fraction increases as the ratio increases, but is found at slightly larger values of A$_v$. At high A$_v$, we see that the CO fraction increases and CH decreases as the ratio increases. In addition the fraction CS decreases and moves towards higher A$_v$.

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

i = 3
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

i = 4
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

# %% [markdown]
# As we increase the metal/grain ratio, the contribution of grain photoelectric effect dominates further into the dark region. There is no grain collison contribution when the metal/grain ratio is lowest. When it is largest, there are also some contributions from Si 1 and not just CrnP, H2dH, and CR H. However, the grain photoelectric never contributes to the heating at the innermost region in any of the models. This region is exclusively H2dH and CR H (and CrnP of the ratio is large enough).

# %%
i_values = [0, 3, 4]
model_names = ['ps2_pdr' + str(i) for i in i_values]

pltspecies=['H','H+','H-','H2','H3+','He+','C','C+','O','O+','CO','OH','H2O']
nspecies=len(pltspecies)

cm = plt.get_cmap('gist_rainbow')
colors=cm(np.arange(nspecies)/nspecies)

plt.figure(figsize=(18,4))

for idx, i in enumerate(i_values, start=1):
    plt.subplot(1, 3, idx)
    for species,color in zip(pltspecies,colors):
        plt.plot(t_mol[i]['AV(point)'],t_mol[i][species]/t_ovr[i]['hden'],label=species,color=color)
    plt.legend()
    plt.yscale("log")
    plt.xlabel("$A_V$")
    plt.ylabel("n(species)/n(H)")
    plt.title("Fractional species/ion abundance: " + model_names[idx-1])
    plt.ylim((1e-11,2))

plt.tight_layout()
plt.show()

# %% [markdown]
# Similar to when we increased the density in the previous example, the distance into the cloud at which the molecule fraction begins to increase becomes larger as the ratio increases.

# %%
i_values = [1, 3, 4]
model_names = ['ps2_pdr' + str(i) for i in i_values]

plt.figure(figsize=(14, 10))

for idx, i in enumerate(i_values, start=1):
    plt.subplot(3, 2, idx*2-1)
    plt.plot(t_ovr[i]['AV(point)'], t_ovr[i]['Te'])
    plt.yscale("log")
    plt.ylabel("$T_e$")
    plt.xlabel("$A_V$")
    plt.title("Temperature vs. A$_V$: " + model_names[idx-1])

    plt.subplot(3, 2, idx*2)
    plt.plot(t_ovr[i]['AV(point)'], t_ovr[i]['eden'] / t_ovr[i]['hden'])
    plt.yscale("log")
    plt.ylabel("$n_e/n_H$")
    plt.xlabel("$A_V$")
    plt.title("Fractional electron density vs. A$_V$: " + model_names[idx-1])

plt.tight_layout()
plt.show()

# %% [markdown]
# As the dust-to-metal ratio increases, there is a more gradual temperature and electron density drop-off. A larger presence of metals (smaller ratio) will lead to more efficient cooling. A larger presence of dust (larger ratio) will lead to more heating from absorption of photons, collisions, and H$_2$ formation on their surfaces.

# %% [markdown]
# ### Changing Cosmic Ray Density:

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)  

i = 5
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)    

i = 6
model_name = 'ps2_pdr' + str(i) 

x_pc = (t_cool_info[i]['depth_cm'].data*u.cm).to('pc').value
x = t_ovr[i]['AV(point)'].data
frac_stackplot(t_cool_frac[i],x,'$A_V$','Cooling: ' + model_name)

# %% [markdown]
# If the cosmic ray density decreases, then there is cooling also due to C 20.0. Besides this, the structure/contribution to cooling does not change much compared to the fiducial model.
#
# However, if the comsic ray density increases, then O 10.0 dominates across nearly the entire region.

# %%
i = 0
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

i = 5
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

i = 6
model_name = 'ps2_pdr' + str(i) 

x = t_ovr[i]['AV(point)'].data   
frac_stackplot(t_heat_frac[i],x,'$A_V$','Heating: ' + model_name)

# %% [markdown]
# At a low cosmic ray density, naturally the heating due to cosmic rays becomes negligible. There is just grain photoelectric effect at low A$_v$ and and grain collisions at high A$_v$.
#
# At high cosmic ray density, about 70 percent of the heating is from cosmic rays at A$_v$ > 3. The grain photoelectric effect always dominates in the inner region, despite the cosmic ray density.

# %%
i_values = [0, 5, 6]
model_names = ['ps2_pdr' + str(i) for i in i_values]

pltspecies=['H','H+','H-','H2','H3+','He+','C','C+','O','O+','CO','OH','H2O']
nspecies=len(pltspecies)

cm = plt.get_cmap('gist_rainbow')
colors=cm(np.arange(nspecies)/nspecies)

plt.figure(figsize=(18,4))

for idx, i in enumerate(i_values, start=1):
    plt.subplot(1, 3, idx)
    for species,color in zip(pltspecies,colors):
        plt.plot(t_mol[i]['AV(point)'],t_mol[i][species]/t_ovr[i]['hden'],label=species,color=color)
    plt.legend()
    plt.yscale("log")
    plt.xlabel("$A_V$")
    plt.ylabel("n(species)/n(H)")
    plt.title("Fractional species/ion abundance: " + model_names[idx-1])
    plt.ylim((1e-11,2))

plt.tight_layout()
plt.show()

# %% [markdown]
# An increase in cosmic ray density does not change the A$_v$ value at which H$_2$ occurs. In addition, beyond the fiducial model density, there seems to be no change in the A$_v$ value at which CO, OH, and H$_2$O exist. If the cosmic ray density is large enough, then it seems as though H- persists across the entire region. In addition, at such a large cosmic ray density, the fraction of H remains quite high, resulting in less H$_2$. There is also more OH and H$_2$O across a larger range of A$_v$, but less CO at large values of A$_v$.

# %%
i_values = [1, 5, 6]
model_names = ['ps2_pdr' + str(i) for i in i_values]

plt.figure(figsize=(14, 10))

for idx, i in enumerate(i_values, start=1):
    plt.subplot(3, 2, idx*2-1)
    plt.plot(t_ovr[i]['AV(point)'], t_ovr[i]['Te'])
    plt.yscale("log")
    plt.ylabel("$T_e$")
    plt.xlabel("$A_V$")
    plt.title("Temperature vs. A$_V$: " + model_names[idx-1])

    plt.subplot(3, 2, idx*2)
    plt.plot(t_ovr[i]['AV(point)'], t_ovr[i]['eden'] / t_ovr[i]['hden'])
    plt.yscale("log")
    plt.ylabel("$n_e/n_H$")
    plt.xlabel("$A_V$")
    plt.title("Fractional electron density vs. A$_V$: " + model_names[idx-1])

plt.tight_layout()
plt.show()

# %% [markdown]
# The temperature profile and electron density are steepest in the fiducial model, where the comsic ray density is at the intermediate value. The temperature profile and electron density are most gradual for the lowest cosmic ray density, similar to the above examples of the lowest hydrogen density and largest dust-to-metal ratio.

# %% [markdown]
# ## __Extra Plotting__:

# %% [markdown]
# ## Plot Te, ne vs. Av

# %%
plt.figure(figsize=(9,6))
plt.plot(t_ovr['AV(point)'],t_ovr['Te'])
plt.yscale("log")
plt.ylabel("$T_e$")
plt.xlabel("$A_V$")
plt.title("Temperature vs. A$_V$: "+model_name)
plt.show()

plt.figure(figsize=(9,6))
plt.plot(t_ovr['AV(point)'],t_ovr['eden']/t_ovr['hden'])
plt.yscale("log")
plt.ylabel("$n_e/n_H$")
plt.xlabel("$A_V$")
plt.title("Fractional electron density vs. A$_V$:"+model_name)
plt.show()

# %%
print(t_mol.colnames)

# %% [markdown]
# ## Plot species/ion fractions

# %%
# This is an example of species to plot, you might want to select others from above!
pltspecies=['H','H+','H-','H2','H3+','He+','C','C+','O','O+','CO','OH','H2O']
nspecies=len(pltspecies)

cm = plt.get_cmap('gist_rainbow')
colors=cm(np.arange(nspecies)/nspecies)

plt.figure(figsize=(9,6)) 
for species,color in zip(pltspecies,colors):
    plt.plot(t_mol['AV(point)'],t_mol[species]/t_ovr['hden'],label=species,color=color)
   
plt.legend()
plt.yscale("log")
plt.xlabel("$A_V$")
plt.ylabel("n(species)/n(H)")
plt.title("Fractional species/ion abundance: "+model_name)
#plt.xlim((2,5))
plt.ylim((1e-11,2))
plt.show()
